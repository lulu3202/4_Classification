# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#converting categorical to numerical value
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import GridSearchCV

# Define the parameter grid for GridSearchCV
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2, 4]
}

# Store the best model under grid parameter; f1_weighted can be suited for imbalanced data
grid = GridSearchCV(DecisionTreeClassifier(random_state=0), param_grid, 
                    refit=True, verbose=3, n_jobs=-1, scoring='f1_weighted')


# Fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5]},
#              scoring='f1_weighted', verbose=3)

# %%
# Print the best parameters after tuning
#print("Best Parameters:", grid.best_params_)

# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)


# Store cross-validation results
cv_results = grid.cv_results_
# Uncomment to print all cross-validation results
# print(cv_results)

# Using the final best fit model to test X_test
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# %%
#generate classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90        85
#            1       0.83      0.80      0.81        49
#
#     accuracy                           0.87       134
#    macro avg       0.86      0.85      0.85       134
# weighted avg       0.86      0.87      0.87       134

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.8847539015606242)

# %%
print(cm)
# Out:
# [[77  8]
#  [10 39]]

# %%
grid.predict([[40,300,1,]])
# Out:
# C:\Anaconda\envs\aiml\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.019446      0.007317         0.020504        0.005010
# 1        0.015616      0.004391         0.018569        0.000954
# 2        0.011428      0.004188         0.019483        0.004197
# 3        0.010642      0.004415         0.016509        0.005075
# 4        0.012077      0.003893         0.014567        0.003266
# 5        0.013518      0.004462         0.020171        0.008352
# 6        0.014094      0.005343         0.024557        0.010233
# 7        0.013064      0.003355         0.018883        0.005118
# 8        0.012751      0.003839         0.025916        0.010068
# 9        0.014364      0.006503         0.027002        0.011055
# 10       0.013159      0.006445         0.021808        0.008398
# 11       0.017518      0.007089         0.016534        0.007253
# 12       0.015434      0.009505         0.014791        0.004422
# 13       0.015938      0.003907         0.019934        0.007901
# 14       0.013568      0.006438         0.013016        0.006344
# 15       0.015714      0.005331         0.018354        0.008026
# 16       0.011314      0.002882         0.013565        0.002811
# 17       0.007472      0.003192         0.020267        0.005511
# 18       0.013617      0.005999         0.017417        0.004582
# 19       0.008974      0.003495         0.018330        0.005943
# 20       0.019909      0.008348         0.020772        0.006430
# 21       0.013565      0.002498         0.016412        0.003644
# 22       0.021205      0.008256         0.020656        0.005666
# 23       0.019739      0.008128         0.012760        0.003410
# 24       0.018270      0.005669         0.017585        0.003244
# 25       0.016197      0.005413         0.013192        0.004101
# 26       0.012577      0.002726         0.014541        0.005610
# 27       0.014604      0.003678         0.014681        0.000725
# 28       0.013127      0.003714         0.014823        0.001531
# 29       0.009877      0.006242         0.017747        0.007252
# 30       0.013998      0.004451         0.016826        0.009427
# 31       0.016814      0.008625         0.014725        0.003960
# 32       0.015645      0.003263         0.016720        0.006699
# 33       0.014819      0.005987         0.019296        0.008194
# 34       0.017616      0.005021         0.016234        0.007467
# 35       0.018097      0.006424         0.015855        0.003621
#
#    param_criterion param_max_depth  param_min_samples_leaf  \
# 0             gini            None                       1
# 1             gini            None                       1
# 2             gini            None                       2
# 3             gini            None                       2
# 4             gini            None                       4
# 5             gini            None                       4
# 6             gini              10                       1
# 7             gini              10                       1
# 8             gini              10                       2
# 9             gini              10                       2
# 10            gini              10                       4
# 11            gini              10                       4
# 12            gini              20                       1
# 13            gini              20                       1
# 14            gini              20                       2
# 15            gini              20                       2
# 16            gini              20                       4
# 17            gini              20                       4
# 18         entropy            None                       1
# 19         entropy            None                       1
# 20         entropy            None                       2
# 21         entropy            None                       2
# 22         entropy            None                       4
# 23         entropy            None                       4
# 24         entropy              10                       1
# 25         entropy              10                       1
# 26         entropy              10                       2
# 27         entropy              10                       2
# 28         entropy              10                       4
# 29         entropy              10                       4
# 30         entropy              20                       1
# 31         entropy              20                       1
# 32         entropy              20                       2
# 33         entropy              20                       2
# 34         entropy              20                       4
# 35         entropy              20                       4
#
#     param_min_samples_split  \
# 0                         2
# 1                         5
# 2                         2
# 3                         5
# 4                         2
# 5                         5
# 6                         2
# 7                         5
# 8                         2
# 9                         5
# 10                        2
# 11                        5
# 12                        2
# 13                        5
# 14                        2
# 15                        5
# 16                        2
# 17                        5
# 18                        2
# 19                        5
# 20                        2
# 21                        5
# 22                        2
# 23                        5
# 24                        2
# 25                        5
# 26                        2
# 27                        5
# 28                        2
# 29                        5
# 30                        2
# 31                        5
# 32                        2
# 33                        5
# 34                        2
# 35                        5
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': None, 'min_...           0.829615
# 1   {'criterion': 'gini', 'max_depth': None, 'min_...           0.867478
# 2   {'criterion': 'gini', 'max_depth': None, 'min_...           0.867478
# 3   {'criterion': 'gini', 'max_depth': None, 'min_...           0.867478
# 4   {'criterion': 'gini', 'max_depth': None, 'min_...           0.759544
# 5   {'criterion': 'gini', 'max_depth': None, 'min_...           0.759544
# 6   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.829615
# 7   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.867478
# 8   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.867478
# 9   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.867478
# 10  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.759544
# 11  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.759544
# 12  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.829615
# 13  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.867478
# 14  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.867478
# 15  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.867478
# 16  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.759544
# 17  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.759544
# 18  {'criterion': 'entropy', 'max_depth': None, 'm...           0.829615
# 19  {'criterion': 'entropy', 'max_depth': None, 'm...           0.867478
# 20  {'criterion': 'entropy', 'max_depth': None, 'm...           0.847141
# 21  {'criterion': 'entropy', 'max_depth': None, 'm...           0.867478
# 22  {'criterion': 'entropy', 'max_depth': None, 'm...           0.759544
# 23  {'criterion': 'entropy', 'max_depth': None, 'm...           0.759544
# 24  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.829615
# 25  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.867478
# 26  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.847141
# 27  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.867478
# 28  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.759544
# 29  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.759544
# 30  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.829615
# 31  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.867478
# 32  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.847141
# 33  {'criterion': 'entropy', 'max_depth': 20, 'min...           0