# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#converting categorical to numerical value
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for GridSearchCV
param_grid = {
    'n_neighbors': [3, 5, 7, 10],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

# Store the best model under grid parameter; f1_weighted can be suited for imbalanced data
grid = GridSearchCV(KNeighborsClassifier(), param_grid, 
                    refit=True, verbose=3, n_jobs=-1, scoring='f1_weighted')

# Fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7, 10],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
# Store cross-validation results
cv_results = grid.cv_results_
# Uncomment to print all cross-validation results
# print(cv_results)

# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)

# Using the final best fit model to test X_test
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82        85
#            1       0.69      0.67      0.68        49
#
#     accuracy                           0.77       134
#    macro avg       0.75      0.75      0.75       134
# weighted avg       0.77      0.77      0.77       134

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.8116446578631453)

# %%
print(cm)
# Out:
# [[70 15]
#  [16 33]]

# %%
grid.predict([[40,300,1,]])
# Out:
# C:\Anaconda\envs\aiml\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.014325      0.005010         0.022806        0.004928
# 1        0.008839      0.005135         0.015073        0.003539
# 2        0.004535      0.002490         0.024507        0.002561
# 3        0.006981      0.002945         0.014426        0.003760
# 4        0.004676      0.003031         0.022078        0.004343
# 5        0.003557      0.007113         0.016241        0.001470
# 6        0.007946      0.002570         0.020918        0.002523
# 7        0.006248      0.003220         0.010876        0.005050
# 8        0.011054      0.002538         0.017789        0.003699
# 9        0.007098      0.003729         0.010905        0.003363
# 10       0.008505      0.002743         0.024805        0.004814
# 11       0.007683      0.001897         0.010921        0.001346
# 12       0.008867      0.005541         0.023489        0.001855
# 13       0.006367      0.004832         0.013684        0.002009
# 14       0.005073      0.003141         0.024439        0.005000
# 15       0.006586      0.001109         0.013688        0.004566
# 16       0.004741      0.003420         0.025299        0.003012
# 17       0.006220      0.002617         0.013290        0.003543
# 18       0.006658      0.001999         0.023372        0.003102
# 19       0.004463      0.001927         0.011638        0.004479
# 20       0.009985      0.003690         0.023511        0.003472
# 21       0.008266      0.000929         0.011317        0.003049
# 22       0.005372      0.002766         0.023851        0.003174
# 23       0.004888      0.005010         0.013831        0.002863
# 24       0.005814      0.001128         0.021948        0.000955
# 25       0.007706      0.004001         0.012366        0.004208
# 26       0.007751      0.003625         0.021943        0.001915
# 27       0.002995      0.002067         0.015416        0.005306
# 28       0.006090      0.005225         0.023408        0.006807
# 29       0.007028      0.001762         0.014160        0.004413
# 30       0.003088      0.004401         0.025916        0.003205
# 31       0.004350      0.000919         0.010264        0.005559
#
#    param_algorithm  param_n_neighbors param_weights  \
# 0             auto                  3       uniform
# 1             auto                  3      distance
# 2             auto                  5       uniform
# 3             auto                  5      distance
# 4             auto                  7       uniform
# 5             auto                  7      distance
# 6             auto                 10       uniform
# 7             auto                 10      distance
# 8        ball_tree                  3       uniform
# 9        ball_tree                  3      distance
# 10       ball_tree                  5       uniform
# 11       ball_tree                  5      distance
# 12       ball_tree                  7       uniform
# 13       ball_tree                  7      distance
# 14       ball_tree                 10       uniform
# 15       ball_tree                 10      distance
# 16         kd_tree                  3       uniform
# 17         kd_tree                  3      distance
# 18         kd_tree                  5       uniform
# 19         kd_tree                  5      distance
# 20         kd_tree                  7       uniform
# 21         kd_tree                  7      distance
# 22         kd_tree                 10       uniform
# 23         kd_tree                 10      distance
# 24           brute                  3       uniform
# 25           brute                  3      distance
# 26           brute                  5       uniform
# 27           brute                  5      distance
# 28           brute                  7       uniform
# 29           brute                  7      distance
# 30           brute                 10       uniform
# 31           brute                 10      distance
#
#                                                params  split0_test_score  \
# 0   {'algorithm': 'auto', 'n_neighbors': 3, 'weigh...           0.832255
# 1   {'algorithm': 'auto', 'n_neighbors': 3, 'weigh...           0.849794
# 2   {'algorithm': 'auto', 'n_neighbors': 5, 'weigh...           0.757701
# 3   {'algorithm': 'auto', 'n_neighbors': 5, 'weigh...           0.832255
# 4   {'algorithm': 'auto', 'n_neighbors': 7, 'weigh...           0.753889
# 5   {'algorithm': 'auto', 'n_neighbors': 7, 'weigh...           0.829615
# 6   {'algorithm': 'auto', 'n_neighbors': 10, 'weig...           0.749046
# 7   {'algorithm': 'auto', 'n_neighbors': 10, 'weig...           0.829615
# 8   {'algorithm': 'ball_tree', 'n_neighbors': 3, '...           0.832255
# 9   {'algorithm': 'ball_tree', 'n_neighbors': 3, '...           0.849794
# 10  {'algorithm': 'ball_tree', 'n_neighbors': 5, '...           0.757701
# 11  {'algorithm': 'ball_tree', 'n_neighbors': 5, '...           0.832255
# 12  {'algorithm': 'ball_tree', 'n_neighbors': 7, '...           0.753889
# 13  {'algorithm': 'ball_tree', 'n_neighbors': 7, '...           0.829615
# 14  {'algorithm': 'ball_tree', 'n_neighbors': 10, ...           0.749046
# 15  {'algorithm': 'ball_tree', 'n_neighbors': 10, ...           0.829615
# 16  {'algorithm': 'kd_tree', 'n_neighbors': 3, 'we...           0.832255
# 17  {'algorithm': 'kd_tree', 'n_neighbors': 3, 'we...           0.849794
# 18  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'we...           0.757701
# 19  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'we...           0.832255
# 20  {'algorithm': 'kd_tree', 'n_neighbors': 7, 'we...           0.753889
# 21  {'algorithm': 'kd_tree', 'n_neighbors': 7, 'we...           0.829615
# 22  {'algorithm': 'kd_tree', 'n_neighbors': 10, 'w...           0.749046
# 23  {'algorithm': 'kd_tree', 'n_neighbors': 10, 'w...           0.829615
# 24  {'algorithm': 'brute', 'n_neighbors': 3, 'weig...           0.832255
# 25  {'algorithm': 'brute', 'n_neighbors': 3, 'weig...           0.849794
# 26  {'algorithm': 'brute', 'n_neighbors': 5, 'weig...           0.757701
# 27  {'algorithm': 'brute', 'n_neighbors': 5, 'weig...           0.832255
# 28  {'algorithm': 'brute', 'n_neighbors': 7, 'weig...           0.737140
# 29  {'algorithm': 'brute', 'n_neighbors': 7, 'weig...           0.829615
# 30  {'algorithm': 'brute', 'n_neighbors': 10, 'wei...           0.749046
# 31  {'algorithm': 'brute', 'n_neighbors': 10, 'wei...           0.829615
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0